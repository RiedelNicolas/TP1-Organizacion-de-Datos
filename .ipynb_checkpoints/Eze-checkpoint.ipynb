# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
from bokeh.plotting import figure, output_file, show
from bokeh.io import export_png
from bokeh.io.export import get_screenshot_as_png
import geopandas

# %%
tweets = pd.read_csv('../TP1-Organizacion-de-Datos/csv/train.csv')

# %%
tweets.sample(n = 5)
# Out:
#          id     keyword                        location  \
# 4120   5855   hailstorm                          Heaven
# 7270  10409   whirlwind  Stamford & Cork (& Shropshire)
# 3449   4931    exploded                             NaN
# 5408   7719   panicking                             NaN
# 4673   6643  inundation               Proudly Canadian!
#
#                                                    text  target
# 4120  Summer heat drives bobcats to Calgary backyard...       1
# 7270  I moved to England five years ago today. What ...       1
# 3449  that exploded &amp; brought about the\nbeginni...       0
# 5408  @beauscoven nah man he's panicking. He just fo...       0
# 4673  Well unfortunately for my followers stage pics...       0

# %%
ciudades = pd.read_csv('../TP1-Organizacion-de-Datos/csv/worldcities.csv')

# %%
ciudades.sample(n = 5)
# Out:
#                 city     city_ascii      lat       lng        country iso2  \
# 10064     Brook Park     Brook Park  41.4036  -81.8219  United States   US
# 3515          Itaúna         Itauna -20.0600  -44.5700         Brazil   BR
# 11068  Big Bear City  Big Bear City  34.2536 -116.7903  United States   US
# 1757       Pathānkot      Pathankot  32.2703   75.7200          India   IN
# 5170        Lakeview       Lakeview  40.6775  -73.6493  United States   US
#
#       iso3    admin_name capital  population          id
# 10064  USA          Ohio     NaN     18626.0  1840000594
# 3515   BRA  Minas Gerais     NaN     77400.0  1076321811
# 11068  USA    California     NaN     13186.0  1840017797
# 1757   IND        Punjab     NaN    253987.0  1356878237
# 5170   USA      New York     NaN      6756.0  1840005269

# %%
tweets['location'].isnull().sum()
# Out:
# 2533

# %%
tweets['location'].isnull().mean()
# Out:
# 0.33272034677525286

# %%
location_list = tweets['location'].tolist()

# %%
ciudades_ocurr = tweets['location'].value_counts()

# %%
ciudades_ocurr
# Out:
# USA                             104
# New York                         71
# United States                    50
# London                           45
# Canada                           29
# Nigeria                          28
# UK                               27
# Los Angeles, CA                  26
# India                            24
# Mumbai                           22
# Washington, DC                   21
# Kenya                            20
# Worldwide                        19
# Australia                        18
# Chicago, IL                      18
# California                       17
# Everywhere                       15
# California, USA                  15
# New York, NY                     15
# San Francisco                    14
# United Kingdom                   14
# Florida                          14
# Los Angeles                      13
# Washington, D.C.                 13
# Indonesia                        13
# Toronto                          12
# NYC                              12
# Ireland                          12
# Chicago                          11
# Earth                            11
#                                ...
# The Howling                       1
# Funtua, Nigeria                   1
# Colchester Essex                  1
# Bangor, Co.Down                   1
# Swan River                        1
# North Highlands, CA               1
# Augusta, Maine, 04330             1
# lost in my thoughts               1
# sÌ£o luis                         1
# Hell                              1
# Sunny South florida               1
# walking the tightrope             1
# Des Moines, Iowa                  1
# Kleenex factory                   1
# #keepthefaith J&J                 1
# Inside the Beltway (DC Area)      1
# See the barn of bleakness         1
# Manchester UK                     1
# Fairgrounds Resident              1
# Dorset, UK                        1
# Vineyard                          1
# France                            1
# 316                               1
# Henderson, NV                     1
# The Multiverse                    1
# #KaumElite;#F?VOR;#SMOFC          1
# Metro Manila                      1
# Rochester                         1
#   News                            1
# Murray Hill, New Jersey           1
# Name: location, Length: 3341, dtype: int64

# %%
ciudades_list = ciudades['city_ascii']
ciudades_list = pd.DataFrame(ciudades_list)

# %%
ciudades_list['ocurrencia'] = 0

# %%
ciudades_list
# Out:
#                   city_ascii  ocurrencia
# 0                      Tokyo           0
# 1                   New York           0
# 2                Mexico City           0
# 3                     Mumbai           0
# 4                  Sao Paulo           0
# 5                      Delhi           0
# 6                   Shanghai           0
# 7                    Kolkata           0
# 8                Los Angeles           0
# 9                      Dhaka           0
# 10              Buenos Aires           0
# 11                   Karachi           0
# 12                     Cairo           0
# 13            Rio de Janeiro           0
# 14                     Osaka           0
# 15                   Beijing           0
# 16                    Manila           0
# 17                    Moscow           0
# 18                  Istanbul           0
# 19                     Paris           0
# 20                     Seoul           0
# 21                     Lagos           0
# 22                   Jakarta           0
# 23                 Guangzhou           0
# 24                   Chicago           0
# 25                    London           0
# 26                      Lima           0
# 27                    Tehran           0
# 28                  Kinshasa           0
# 29                    Bogota           0
# ...                      ...         ...
# 15463  Podkamennaya Tunguska           0
# 15464                  Komsa           0
# 15465                 Omchak           0
# 15466             Trofimovsk           0
# 15467               Sagastyr           0
# 15468               Utkholok           0
# 15469                 Siglan           0
# 15470               Pakhachi           0
# 15471            Tunguskhaya           0
# 15472                 Chagda           0
# 15473             Il'pyrskiy           0
# 15474             Shalaurova           0
# 15475                 Chegga           0
# 15476                 Olenek           0
# 15477         Matochkin Shar           0
# 15478               Zvezdnyy           0
# 15479                  Agapa           0
# 15480           Starorybnoye           0
# 15481               Menkerya           0
# 15482                 Tukchi           0
# 15483               Khakhar'           0
# 15484           Zemlya Bunge           0
# 15485            Island Lake           0
# 15486        Big Beaverhouse           0
# 15487                   Nord           0
# 15488            Timmiarmiut           0
# 15489            Cheremoshna           0
# 15490              Ambarchik           0
# 15491                Nordvik           0
# 15492                Ennadai           0
#
# [15493 rows x 2 columns]

# %%
ciudades_list.shape
# Out:
# (15493, 2)

# %%
ciudades_list['city_ascii'].count()
# Out:
# 15493

# %%
ciudades_list['veracidad'] = 0
ciudades_list['cant_verdaderos'] = 0

# %%
ciudades_list['veracidad'] = ciudades_list['veracidad'].astype(float)

# %%
ciudades_list.dtypes
# Out:
# city_ascii          object
# ocurrencia           int64
# veracidad          float64
# cant_verdaderos      int64
# dtype: object

# %%
tienenLaCiudad = pd.DataFrame(columns=('tweetDeLaCiudad', 'V/F'))
tienenLaCiudad['V/F'] = tweets['target']

# %% [markdown]
# Comparo cada ciudad del mundo con los tweets y busco si el nombre de la ciudad esta incluido en el campo "Location" de cada Tweet

# %%
#CUIDADO AL EJECUTAR ESTO xD
for x in range(ciudades_list['city_ascii'].count()):
    ciudad = ciudades_list.loc[x, 'city_ascii']
    if (len(ciudad) > 4):
        tienenLaCiudad['tweetDeLaCiudad'] = tweets.loc[:, 'location'].str.contains(ciudad, regex = False)
    else:
        tienenLaCiudad['tweetDeLaCiudad'] = (tweets.loc[:, 'location'] == ciudad)
        
    cant_tweets = tienenLaCiudad[tienenLaCiudad['tweetDeLaCiudad'] == True]['tweetDeLaCiudad'].count()
    verdaderos = tienenLaCiudad[(tienenLaCiudad['V/F'] == 1) & (tienenLaCiudad['tweetDeLaCiudad'] == True)]['V/F'].count()
    
    ciudades_list.loc[x, 'cant_verdaderos'] = verdaderos
    ciudades_list.loc[x, 'ocurrencia'] = cant_tweets
    if (cant_tweets != 0):
        ciudades_list.loc[x, 'veracidad'] = float(verdaderos)/float(cant_tweets)

# %%
ciudades_list
# Out:
#                   city_ascii  ocurrencia  veracidad  cant_verdaderos
# 0                      Tokyo           8   0.500000                4
# 1                   New York         131   0.320611               42
# 2                Mexico City           1   0.000000                0
# 3                     Mumbai          31   0.838710               26
# 4                  Sao Paulo           2   0.500000                1
# 5                      Delhi          10   0.600000                6
# 6                   Shanghai           1   0.000000                0
# 7                    Kolkata           3   0.333333                1
# 8                Los Angeles          53   0.358491               19
# 9                      Dhaka           2   1.000000                2
# 10              Buenos Aires           5   0.400000                2
# 11                   Karachi           9   1.000000                9
# 12                     Cairo           2   0.500000                1
# 13            Rio de Janeiro           3   0.000000                0
# 14                     Osaka           1   1.000000                1
# 15                   Beijing           0   0.000000                0
# 16                    Manila           6   0.333333                2
# 17                    Moscow           3   0.333333                1
# 18                  Istanbul           2   0.500000                1
# 19                     Paris           6   0.500000                3
# 20                     Seoul           0   0.000000                0
# 21                     Lagos          16   0.687500               11
# 22                   Jakarta           7   0.714286                5
# 23                 Guangzhou           0   0.000000                0
# 24                   Chicago          45   0.444444               20
# 25                    London         108   0.342593               37
# 26                      Lima           0   0.000000                0
# 27                    Tehran           0   0.000000                0
# 28                  Kinshasa           0   0.000000                0
# 29                    Bogota           0   0.000000                0
# ...                      ...         ...        ...              ...
# 15463  Podkamennaya Tunguska           0   0.000000                0
# 15464                  Komsa           0   0.000000                0
# 15465                 Omchak           0   0.000000                0
# 15466             Trofimovsk           0   0.000000                0
# 15467               Sagastyr           0   0.000000                0
# 15468               Utkholok           0   0.000000                0
# 15469                 Siglan           0   0.000000                0
# 15470               Pakhachi           0   0.000000                0
# 15471            Tunguskhaya           0   0.000000                0
# 15472                 Chagda           0   0.000000                0
# 15473             Il'pyrskiy           0   0.000000                0
# 15474             Shalaurova           0   0.000000                0
# 15475                 Chegga           0   0.000000                0
# 15476                 Olenek           0   0.000000                0
# 15477         Matochkin Shar           0   0.000000                0
# 15478               Zvezdnyy           0   0.000000                0
# 15479                  Agapa           0   0.000000                0
# 15480           Starorybnoye           0   0.000000                0
# 15481               Menkerya           0   0.000000                0
# 15482                 Tukchi           0   0.000000                0
# 15483               Khakhar'           0   0.000000                0
# 15484           Zemlya Bunge           0   0.000000                0
# 15485            Island Lake           1   0.000000                0
# 15486        Big Beaverhouse           0   0.000000                0
# 15487                   Nord           0   0.000000                0
# 15488            Timmiarmiut           0   0.000000                0
# 15489            Cheremoshna           0   0.000000                0
# 15490              Ambarchik           0   0.000000                0
# 15491                Nordvik           0   0.000000                0
# 15492                Ennadai           0   0.000000                0
#
# [15493 rows x 4 columns]

# %%
Ciudades_Mas_10_Tweets = (ciudades_list.loc[:,'ocurrencia'] > 10)

# %%
Top_populares = ciudades_list.loc[Ciudades_Mas_10_Tweets]

# %%
Top_populares = Top_populares.sort_values('ocurrencia', ascending = False)

# %%
Top_populares = Top_populares.drop_duplicates(['city_ascii'])

# %%
Top_populares
# Out:
#           city_ascii  ocurrencia  veracidad  cant_verdaderos
# 1           New York         131   0.320611               42
# 1388          London         108   0.342593               37
# 13458     California          77   0.519481               40
# 10449     Washington          67   0.626866               42
# 2638     Los Angeles          53   0.358491               19
# 24           Chicago          45   0.444444               20
# 4296         Florida          35   0.371429               13
# 7676   San Francisco          33   0.545455               18
# 3             Mumbai          31   0.838710               26
# 14904        Atlanta          30   0.366667               11
# 9287         Ontario          27   0.370370               10
# 52           Toronto          26   0.538462               14
# 87           Seattle          25   0.360000                9
# 9870          Oregon          24   0.500000               12
# 10139     Manchester          23   0.304348                7
# 8381          Sydney          22   0.681818               15
# 432          Calgary          22   0.772727               17
# 2653        Carolina          22   0.454545               10
# 105        San Diego          22   0.454545               10
# 47           Houston          20   0.450000                9
# 135           Denver          20   0.650000               13
# 69         Melbourne          19   0.631579               12
# 11197      Charlotte          19   0.526316               10
# 176        Vancouver          19   0.263158                5
# 10278         Dallas          16   0.437500                7
# 21             Lagos          16   0.687500               11
# 14540         Boston          16   0.375000                6
# 11368       Portland          15   0.600000                9
# 2710        Columbia          15   0.533333                8
# 230       Sacramento          15   0.733333               11
# 272           Austin          14   0.428571                6
# 9300        Victoria          14   0.642857                9
# 4414         Indiana          14   0.285714                4
# 12359        Memphis          13   0.615385                8
# 13910      Nashville          13   0.769231               10
# 806       Birmingham          13   0.692308                9
# 11226       Virginia          13   0.615385                8
# 12071         Orland          12   0.166667                2
# 14378      Newcastle          12   0.250000                3
# 9838          Valley          12   0.583333                7
# 40             Miami          12   0.333333                4
# 236          Orlando          12   0.166667                2
# 203        Las Vegas          12   0.416667                5
# 9190           Green          12   0.333333                4
# 116          Nairobi          12   0.750000                9
# 11751       Brooklyn          11   0.272727                3
# 44      Philadelphia          11   0.545455                6

# %%
saltos = np.linspace(0.3, 0.7, 48)
colores = (cm.get_cmap('YlOrBr'))(saltos)
Top_populares = Top_populares.sort_values('ocurrencia')
Top_populares_plot = Top_populares.plot(kind='bar', y ='ocurrencia', x = 'city_ascii', figsize=(15, 30), color=colores, width=0.85)

plt.xticks(np.arange(0, 48, 1.0))
plt.tick_params(axis='y', length=0)

#Top_populares_plot.spines['right'].set_visible(False)
#Top_populares_plot.spines['top'].set_visible(False)
#Top_populares_plot.spines['left'].set_visible(False)
#Top_populares_plot.spines['bottom'].set_visible(False)

lineas = Top_populares_plot.get_xticks()
for i in lineas:
      Top_populares_plot.axvline(x=i, linestyle='--', alpha=0.4, color='#eeeeee')
    
plt.gca().invert_xaxis()

Top_populares_plot.set_xlabel("Ciudad", labelpad=20, weight='bold', size=16)
Top_populares_plot.set_ylabel("Cantidad de Tweets", labelpad=20, weight='bold', size=16)
Top_populares_plot.set_title("Ciudades con mayor cantidad de Tweets", weight='bold', size=20)
# Out:
# Text(0.5,1,'Ciudades con mayor cantidad de Tweets')

# %%
saltos = np.linspace(0.3, 0.7, 50)
colores = (cm.get_cmap('YlOrBr'))(saltos)
Top_populares = Top_populares.sort_values('veracidad')
Top_populares_plot = Top_populares.plot(kind='bar', y ='veracidad', x = 'city_ascii', figsize=(15, 30), color=colores, width=0.85)

plt.xticks(np.arange(0, 47, 1), rotation = 80)
plt.tick_params(axis='y', length=0)

#Top_populares_plot.spines['right'].set_visible(False)
#Top_populares_plot.spines['top'].set_visible(False)
#Top_populares_plot.spines['left'].set_visible(False)
#Top_populares_plot.spines['bottom'].set_visible(False)

lineas = Top_populares_plot.get_xticks()
for i in lineas:
      Top_populares_plot.axvline(x=i, linestyle='--', alpha=0.4, color='#eeeeee')

plt.gca().invert_xaxis()
        
Top_populares_plot.set_xlabel("Ciudad", labelpad=20, weight='bold', size=16)
Top_populares_plot.set_ylabel("Veracidad promedio", labelpad=20, weight='bold', size=16)
Top_populares_plot.set_title("Veracidad promedio de los Tweets por ciudad", weight='bold', size=20)
# Out:
# Text(0.5,1,'Veracidad promedio de los Tweets por ciudad')

# %%
ciudades_list['Pais'] = ciudades['country']

# %%
ciudades_list
# Out:
#                   city_ascii  ocurrencia  veracidad  cant_verdaderos  \
# 0                      Tokyo           8   0.500000                4
# 1                   New York         131   0.320611               42
# 2                Mexico City           1   0.000000                0
# 3                     Mumbai          31   0.838710               26
# 4                  Sao Paulo           2   0.500000                1
# 5                      Delhi          10   0.600000                6
# 6                   Shanghai           1   0.000000                0
# 7                    Kolkata           3   0.333333                1
# 8                Los Angeles          53   0.358491               19
# 9                      Dhaka           2   1.000000                2
# 10              Buenos Aires           5   0.400000                2
# 11                   Karachi           9   1.000000                9
# 12                     Cairo           2   0.500000                1
# 13            Rio de Janeiro           3   0.000000                0
# 14                     Osaka           1   1.000000                1
# 15                   Beijing           0   0.000000                0
# 16                    Manila           6   0.333333                2
# 17                    Moscow           3   0.333333                1
# 18                  Istanbul           2   0.500000                1
# 19                     Paris           6   0.500000                3
# 20                     Seoul           0   0.000000                0
# 21                     Lagos          16   0.687500               11
# 22                   Jakarta           7   0.714286                5
# 23                 Guangzhou           0   0.000000                0
# 24                   Chicago          45   0.444444               20
# 25                    London         108   0.342593               37
# 26                      Lima           0   0.000000                0
# 27                    Tehran           0   0.000000                0
# 28                  Kinshasa           0   0.000000                0
# 29                    Bogota           0   0.000000                0
# ...                      ...         ...        ...              ...
# 15463  Podkamennaya Tunguska           0   0.000000                0
# 15464                  Komsa           0   0.000000                0
# 15465                 Omchak           0   0.000000                0
# 15466             Trofimovsk           0   0.000000                0
# 15467               Sagastyr           0   0.000000                0
# 15468               Utkholok           0   0.000000                0
# 15469                 Siglan           0   0.000000                0
# 15470               Pakhachi           0   0.000000                0
# 15471            Tunguskhaya           0   0.000000                0
# 15472                 Chagda           0   0.000000                0
# 15473             Il'pyrskiy           0   0.000000                0
# 15474             Shalaurova           0   0.000000                0
# 15475                 Chegga           0   0.000000                0
# 15476                 Olenek           0   0.000000                0
# 15477         Matochkin Shar           0   0.000000                0
# 15478               Zvezdnyy           0   0.000000                0
# 15479                  Agapa           0   0.000000                0
# 15480           Starorybnoye           0   0.000000                0
# 15481               Menkerya           0   0.000000                0
# 15482                 Tukchi           0   0.000000                0
# 15483               Khakhar'           0   0.000000                0
# 15484           Zemlya Bunge           0   0.000000                0
# 15485            Island Lake           1   0.000000                0
# 15486        Big Beaverhouse           0   0.000000                0
# 15487                   Nord           0   0.000000                0
# 15488            Timmiarmiut           0   0.000000                0
# 15489            Cheremoshna           0   0.000000                0
# 15490              Ambarchik           0   0.000000                0
# 15491                Nordvik           0   0.000000                0
# 15492                Ennadai           0   0.000000                0
#
#                    Pais
# 0                 Japan
# 1         United States
# 2                Mexico
# 3                 India
# 4                Brazil
# 5                 India
# 6                 China
# 7                 India
# 8         United States
# 9            Bangladesh
# 10            Argentina
# 11             Pakistan
# 12                Egypt
# 13               Brazil
# 14                Japan
# 15                China
# 16          Philippines
# 17               Russia
# 18               Turkey
# 19               France
# 20         Korea, South
# 21              Nigeria
# 22            Indonesia
# 23                China
# 24        United States
# 25       United Kingdom
# 26                 Peru
# 27                 Iran
# 28     Congo (Kinshasa)
# 29             Colombia
# ...                 ...
# 15463            Russia
# 15464            Russia
# 15465            Russia
# 15466            Russia
# 15467            Russia
# 15468            Russia
# 15469            Russia
# 15470            Russia
# 15471            Russia
# 15472            Russia
# 15473            Russia
# 15474            Russia
# 15475        Mauritania
# 15476            Russia
# 15477            Russia
# 15478            Russia
# 15479            Russia
# 15480            Russia
# 15481            Russia
# 15482            Russia
# 15483            Russia
# 15484            Russia
# 15485            Canada
# 15486            Canada
# 15487         Greenland
# 15488         Greenland
# 15489           Ukraine
# 15490            Russia
# 15491            Russia
# 15492            Canada
#
# [15493 rows x 5 columns]

# %%
ciudades_list = ciudades_list.drop_duplicates('city_ascii', keep = 'first')

# %%
ciudades_list.shape
# Out:
# (13482, 5)

# %%
Tweets_Paises = pd.DataFrame({'Cantidad_Tweets': 0, 'Pais': ciudades['country'], 'Veracidad': 0, 'Cantidad_Tweets_Verdaderos': 0})

# %%
Tweets_Paises['Veracidad'] = Tweets_Paises['Veracidad'].astype(float)

# %%
Tweets_Paises['Pais'].describe()
# Out:
# count             15493
# unique              223
# top       United States
# freq               7328
# Name: Pais, dtype: object

# %%
Tweets_Paises = Tweets_Paises.drop_duplicates(['Pais'])
Tweets_Paises = Tweets_Paises.reset_index(drop = True)

# %%
Tweets_Paises.dtypes
# Out:
# Cantidad_Tweets                 int64
# Cantidad_Tweets_Verdaderos      int64
# Pais                           object
# Veracidad                     float64
# dtype: object

# %%
ciudades_list.dtypes
# Out:
# city_ascii          object
# ocurrencia           int64
# veracidad          float64
# cant_verdaderos      int64
# Pais                object
# dtype: object

# %%
ciudades_list
# Out:
#                   city_ascii  ocurrencia  veracidad  cant_verdaderos  \
# 0                      Tokyo           8   0.500000                4
# 1                   New York         131   0.320611               42
# 2                Mexico City           1   0.000000                0
# 3                     Mumbai          31   0.838710               26
# 4                  Sao Paulo           2   0.500000                1
# 5                      Delhi          10   0.600000                6
# 6                   Shanghai           1   0.000000                0
# 7                    Kolkata           3   0.333333                1
# 8                Los Angeles          53   0.358491               19
# 9                      Dhaka           2   1.000000                2
# 10              Buenos Aires           5   0.400000                2
# 11                   Karachi           9   1.000000                9
# 12                     Cairo           2   0.500000                1
# 13            Rio de Janeiro           3   0.000000                0
# 14                     Osaka           1   1.000000                1
# 15                   Beijing           0   0.000000                0
# 16                    Manila           6   0.333333                2
# 17                    Moscow           3   0.333333                1
# 18                  Istanbul           2   0.500000                1
# 19                     Paris           6   0.500000                3
# 20                     Seoul           0   0.000000                0
# 21                     Lagos          16   0.687500               11
# 22                   Jakarta           7   0.714286                5
# 23                 Guangzhou           0   0.000000                0
# 24                   Chicago          45   0.444444               20
# 25                    London         108   0.342593               37
# 26                      Lima           0   0.000000                0
# 27                    Tehran           0   0.000000                0
# 28                  Kinshasa           0   0.000000                0
# 29                    Bogota           0   0.000000                0
# ...                      ...         ...        ...              ...
# 15462                 Indiga           0   0.000000                0
# 15463  Podkamennaya Tunguska           0   0.000000                0
# 15464                  Komsa           0   0.000000                0
# 15465                 Omchak           0   0.000000                0
# 15466             Trofimovsk           0   0.000000                0
# 15467               Sagastyr           0   0.000000                0
# 15468               Utkholok           0   0.000000                0
# 15469                 Siglan           0   0.000000                0
# 15470               Pakhachi           0   0.000000                0
# 15471            Tunguskhaya           0   0.000000                0
# 15472                 Chagda           0   0.000000                0
# 15473             Il'pyrskiy           0   0.000000                0
# 15474             Shalaurova           0   0.000000                0
# 15475                 Chegga           0   0.000000                0
# 15476                 Olenek           0   0.000000                0
# 15477         Matochkin Shar           0   0.000000                0
# 15478               Zvezdnyy           0   0.000000                0
# 15479                  Agapa           0   0.000000                0
# 15480           Starorybnoye           0   0.000000                0
# 15481               Menkerya           0   0.000000                0
# 15482                 Tukchi           0   0.000000                0
# 15483               Khakhar'           0   0.000000                0
# 15484           Zemlya Bunge           0   0.000000                0
# 15486        Big Beaverhouse           0   0.000000                0
# 15487                   Nord           0   0.000000                0
# 15488            Timmiarmiut           0   0.000000                0
# 15489            Cheremoshna           0   0.000000                0
# 15490              Ambarchik           0   0.000000                0
# 15491                Nordvik           0   0.000000                0
# 15492                Ennadai           0   0.000000                0
#
#                    Pais
# 0                 Japan
# 1         United States
# 2                Mexico
# 3                 India
# 4                Brazil
# 5                 India
# 6                 China
# 7                 India
# 8         United States
# 9            Bangladesh
# 10            Argentina
# 11             Pakistan
# 12                Egypt
# 13               Brazil
# 14                Japan
# 15                China
# 16          Philippines
# 17               Russia
# 18               Turkey
# 19               France
# 20         Korea, South
# 21              Nigeria
# 22            Indonesia
# 23                China
# 24        United States
# 25       United Kingdom
# 26                 Peru
# 27                 Iran
# 28     Congo (Kinshasa)
# 29             Colombia
# ...                 ...
# 15462            Russia
# 15463            Russia
# 15464            Russia
# 15465            Russia
# 15466            Russia
# 15467            Russia
# 15468            Russia
# 15469            Russia
# 15470            Russia
# 15471            Russia
# 15472            Russia
# 15473            Russia
# 15474            Russia
# 15475        Mauritania
# 15476            Russia
# 15477            Russia
# 15478            Russia
# 15479            Russia
# 15480            Russia
# 15481            Russia
# 15482            Russia
# 15483            Russia
# 15484            Russia
# 15486            Canada
# 15487         Greenland
# 15488         Greenland
# 15489           Ukraine
# 15490            Russia
# 15491            Russia
# 15492            Canada
#
# [13482 rows x 5 columns]

# %%
#CUIDADO AL EJECUTAR ESTO xD
for w in range(Tweets_Paises['Pais'].count()):
    
    pais = Tweets_Paises.loc[w, 'Pais']
    
    la_ciudad_es_del_pais = ciudades_list.loc[:, 'Pais'].str.contains(pais , regex = False)
    
    ciudades_del_pais = ciudades_list.loc[la_ciudad_es_del_pais]
    
    total_tweets_pais = ciudades_del_pais['ocurrencia'].sum()

    total_tweets_verdaderos_pais = ciudades_del_pais['cant_verdaderos'].sum()
    
    Tweets_Paises.loc[w, 'Cantidad_Tweets'] = total_tweets_pais
    
    Tweets_Paises.loc[w, 'Cantidad_Tweets_Verdaderos'] = total_tweets_verdaderos_pais
    
    if (total_tweets_pais != 0):
        
        Tweets_Paises.loc[w, 'Veracidad'] = float(total_tweets_verdaderos_pais)/float(total_tweets_pais)

# %%
Tweets_Paises
# Out:
#      Cantidad_Tweets  Cantidad_Tweets_Verdaderos  \
# 0                 13                           7
# 1               1906                         839
# 2                  8                           4
# 3                 75                          52
# 4                 16                           5
# 5                  3                           1
# 6                  2                           2
# 7                  8                           3
# 8                 14                          12
# 9                  6                           4
# 10                13                           6
# 11                 7                           2
# 12                 7                           4
# 13                17                           7
# 14                 0                           0
# 15                34                          24
# 16                18                          12
# 17               275                          95
# 18                 0                           0
# 19                 0                           0
# 20                 1                           0
# 21                 0                           0
# 22                 4                           3
# 23                 0                           0
# 24                 3                           2
# 25                 5                           3
# 26                10                           4
# 27                 0                           0
# 28               111                          59
# 29                 8                           2
# ..               ...                         ...
# 193                0                           0
# 194                0                           0
# 195                1                           1
# 196                0                           0
# 197                0                           0
# 198                0                           0
# 199                0                           0
# 200                0                           0
# 201                0                           0
# 202                0                           0
# 203               25                          13
# 204                0                           0
# 205                0                           0
# 206                0                           0
# 207                0                           0
# 208                0                           0
# 209                0                           0
# 210                0                           0
# 211                0                           0
# 212                0                           0
# 213                0                           0
# 214                0                           0
# 215                0                           0
# 216                0                           0
# 217                0                           0
# 218                0                           0
# 219                0                           0
# 220                0                           0
# 221                0                           0
# 222                0                           0
#
#                                               Pais  Veracidad
# 0                                            Japan   0.538462
# 1                                    United States   0.440189
# 2                                           Mexico   0.500000
# 3                                            India   0.693333
# 4                                           Brazil   0.312500
# 5                                            China   0.333333
# 6                                       Bangladesh   1.000000
# 7                                        Argentina   0.375000
# 8                                         Pakistan   0.857143
# 9                                            Egypt   0.666667
# 10                                     Philippines   0.461538
# 11                                          Russia   0.285714
# 12                                          Turkey   0.571429
# 13                                          France   0.411765
# 14                                    Korea, South   0.000000
# 15                                         Nigeria   0.705882
# 16                                       Indonesia   0.666667
# 17                                  United Kingdom   0.345455
# 18                                            Peru   0.000000
# 19                                            Iran   0.000000
# 20                                Congo (Kinshasa)   0.000000
# 21                                        Colombia   0.000000
# 22                                       Hong Kong   0.750000
# 23                                          Taiwan   0.000000
# 24                                        Thailand   0.666667
# 25                                           Chile   0.600000
# 26                                           Spain   0.400000
# 27                                         Vietnam   0.000000
# 28                                          Canada   0.531532
# 29                                       Singapore   0.250000
# ..                                             ...        ...
# 193                                 American Samoa   0.000000
# 194                                         Tuvalu   0.000000
# 195                Micronesia, Federated States Of   1.000000
# 196                       Northern Mariana Islands   0.000000
# 197                                           Guam   0.000000
# 198                                      West Bank   0.000000
# 199                                   Sint Maarten   0.000000
# 200                                         Kosovo   0.000000
# 201                                          Palau   0.000000
# 202                                          Macau   0.000000
# 203                                    Puerto Rico   0.520000
# 204                                     Martinique   0.000000
# 205                                        Reunion   0.000000
# 206                                      Gibraltar   0.000000
# 207                                     Guadeloupe   0.000000
# 208                               French Polynesia   0.000000
# 209                                  New Caledonia   0.000000
# 210                                  French Guiana   0.000000
# 211                                        Mayotte   0.000000
# 212                                      Greenland   0.000000
# 213                                  Faroe Islands   0.000000
# 214                              Wallis And Futuna   0.000000
# 215  Saint Helena, Ascension, And Tristan Da Cunha   0.000000
# 216                                        Bermuda   0.000000
# 217                                    Isle Of Man   0.000000
# 218                       Turks And Caicos Islands   0.000000
# 219                                 Cayman Islands   0.000000
# 220                                   Cook Islands   0.000000
# 221              Falkland Islands (Islas Malvinas)   0.000000
# 222       South Georgia And South Sandwich Islands   0.000000
#
# [223 rows x 4 columns]

# %%
Tweets_Paises['Cantidad_Tweets'].sum()
# Out:
# 2970

# %%
paises_mas_10_tweets = (Tweets_Paises.loc[:,'Cantidad_Tweets'] > 10)

# %%
paises_mas_10_tweets = Tweets_Paises.loc[paises_mas_10_tweets]

# %%
paises_mas_10_tweets = paises_mas_10_tweets.sort_values('Cantidad_Tweets')

# %%
saltos = np.linspace(0.3, 0.7, 20)
colores = (cm.get_cmap('YlOrBr'))(saltos)

paises_mas_10_tweets_plot = paises_mas_10_tweets.plot(kind='bar', y ='Cantidad_Tweets', x = 'Pais', figsize=(15, 15), color=colores, width=0.85)

plt.xticks(np.arange(0, 19, 1.0))
plt.tick_params(axis='y', length=0)

#paises_mas_10_tweets_plot.spines['right'].set_visible(False)
#paises_mas_10_tweets_plot.spines['top'].set_visible(False)
#paises_mas_10_tweets_plot.spines['left'].set_visible(False)
#paises_mas_10_tweets_plot.spines['bottom'].set_visible(False)

lineas = paises_mas_10_tweets_plot.get_xticks()
for i in lineas:
      paises_mas_10_tweets_plot.axvline(x=i, linestyle='--', alpha=0.4, color='#eeeeee')
        
plt.xticks(fontsize = 10, rotation = 40)
plt.yticks(fontsize = 10)

plt.gca().invert_xaxis()

paises_mas_10_tweets_plot.set_xlabel("Pais", labelpad=20, weight='bold', size=16)
paises_mas_10_tweets_plot.set_ylabel("Cantidad de Tweets", labelpad=20, weight='bold', size=16)
paises_mas_10_tweets_plot.set_title("Paises con mayor cantidad de Tweets", weight='bold', size=20)
# Out:
# Text(0.5,1,'Paises con mayor cantidad de Tweets')

# %%
saltos = np.linspace(0.3, 0.7, 20)
colores = (cm.get_cmap('YlOrBr'))(saltos)

paises_mas_10_tweets_plot = paises_mas_10_tweets.plot(kind='bar', y ='Veracidad', x = 'Pais', figsize=(30,10), color=colores, width=0.80)

paises_mas_10_tweets_plot.spines['right'].set_visible(False)
paises_mas_10_tweets_plot.spines['top'].set_visible(False)
paises_mas_10_tweets_plot.spines['left'].set_visible(False)
paises_mas_10_tweets_plot.spines['bottom'].set_visible(False)

lineas = paises_mas_10_tweets_plot.get_xticks()
for i in lineas:
      paises_mas_10_tweets_plot.axvline(x=i, linestyle='--', alpha=0.4, color='#eeeeee')
             
plt.xticks(fontsize = 15, rotation = 40)
plt.yticks(fontsize = 15)

paises_mas_10_tweets_plot.set_xlabel("Pais", labelpad=20, weight='bold', size=16)
paises_mas_10_tweets_plot.set_ylabel("Veracidad promedio", labelpad=20, weight='bold', size=16)
paises_mas_10_tweets_plot.set_title("Veracidad promedio de los Tweets por pais", weight='bold', size=20)
# Out:
# Text(0.5,1,'Veracidad promedio de los Tweets por pais')

# %% [markdown]
# Veracidad de los tweets cuando la locacion es "valida"

# %%
Tweets_Paises['Cantidad_Tweets'].sum()
# Out:
# 2970

# %%
Tweets_Paises['Cantidad_Tweets_Verdaderos'].sum()
# Out:
# 1359

# %%
float(Tweets_Paises['Cantidad_Tweets_Verdaderos'].sum())/float(Tweets_Paises['Cantidad_Tweets'].sum())
# Out:
# 0.4575757575757576

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %%
Tweets_Verdaderos_Locations_Invalidas = (tweets['target'].sum() - Tweets_Paises['Cantidad_Tweets_Verdaderos'].sum())

# %%
Tweets_Verdaderos_Locations_Invalidas
# Out:
# 1912

# %%
Tweets_Totales_Locations_Invalidas = (tweets['id'].count() - Tweets_Paises['Cantidad_Tweets'].sum())

# %%
Tweets_Totales_Locations_Invalidas
# Out:
# 4643

# %%
float(Tweets_Verdaderos_Locations_Invalidas)/float(Tweets_Totales_Locations_Invalidas)
# Out:
# 0.4118027137626535

# %% [markdown]
# Cuando la location es invalida hay una ligera diferencia entre la veracidad de los Tweets

# %%
ciudades_list = ciudades_list.reset_index(drop = True)

# %%
ciudades = ciudades.drop_duplicates('city_ascii', keep = 'first')

# %%
ciudades = ciudades.reset_index(drop = True) # A ciudades_list ya le habia hecho el drop_duplicates antes.

# %%
ciudades_list['cant_habitantes'] = ciudades['population']

# %%
ciudades_list
# Out:
#                   city_ascii  ocurrencia  veracidad  cant_verdaderos  \
# 0                      Tokyo           8   0.500000                4
# 1                   New York         131   0.320611               42
# 2                Mexico City           1   0.000000                0
# 3                     Mumbai          31   0.838710               26
# 4                  Sao Paulo           2   0.500000                1
# 5                      Delhi          10   0.600000                6
# 6                   Shanghai           1   0.000000                0
# 7                    Kolkata           3   0.333333                1
# 8                Los Angeles          53   0.358491               19
# 9                      Dhaka           2   1.000000                2
# 10              Buenos Aires           5   0.400000                2
# 11                   Karachi           9   1.000000                9
# 12                     Cairo           2   0.500000                1
# 13            Rio de Janeiro           3   0.000000                0
# 14                     Osaka           1   1.000000                1
# 15                   Beijing           0   0.000000                0
# 16                    Manila           6   0.333333                2
# 17                    Moscow           3   0.333333                1
# 18                  Istanbul           2   0.500000                1
# 19                     Paris           6   0.500000                3
# 20                     Seoul           0   0.000000                0
# 21                     Lagos          16   0.687500               11
# 22                   Jakarta           7   0.714286                5
# 23                 Guangzhou           0   0.000000                0
# 24                   Chicago          45   0.444444               20
# 25                    London         108   0.342593               37
# 26                      Lima           0   0.000000                0
# 27                    Tehran           0   0.000000                0
# 28                  Kinshasa           0   0.000000                0
# 29                    Bogota           0   0.000000                0
# ...                      ...         ...        ...              ...
# 13452                 Indiga           0   0.000000                0
# 13453  Podkamennaya Tunguska           0   0.000000                0
# 13454                  Komsa           0   0.000000                0
# 13455                 Omchak           0   0.000000                0
# 13456             Trofimovsk           0   0.000000                0
# 13457               Sagastyr           0   0.000000                0
# 13458               Utkholok           0   0.000000                0
# 13459                 Siglan           0   0.000000                0
# 13460               Pakhachi           0   0.000000                0
# 13461            Tunguskhaya           0   0.000000                0
# 13462                 Chagda           0   0.000000                0
# 13463             Il'pyrskiy           0   0.000000                0
# 13464             Shalaurova           0   0.000000                0
# 13465                 Chegga           0   0.000000                0
# 13466                 Olenek           0   0.000000                0
# 13467         Matochkin Shar           0   0.000000                0
# 13468               Zvezdnyy           0   0.000000                0
# 13469                  Agapa           0   0.000000                0
# 13470           Starorybnoye           0   0.000000                0
# 13471               Menkerya           0   0.000000                0
# 13472                 Tukchi           0   0.000000                0
# 13473               Khakhar'           0   0.000000                0
# 13474           Zemlya Bunge           0   0.000000                0
# 13475        Big Beaverhouse           0   0.000000                0
# 13476                   Nord           0   0.000000                0
# 13477            Timmiarmiut           0   0.000000                0
# 13478            Cheremoshna           0   0.000000                0
# 13479              Ambarchik           0   0.000000                0
# 13480                Nordvik           0   0.000000                0
# 13481                Ennadai           0   0.000000                0
#
#                    Pais  cant_habitantes
# 0                 Japan       35676000.0
# 1         United States       19354922.0
# 2                Mexico       19028000.0
# 3                 India       18978000.0
# 4                Brazil       18845000.0
# 5                 India       15926000.0
# 6                 China       14987000.0
# 7                 India       14787000.0
# 8         United States       12815475.0
# 9            Bangladesh       12797394.0
# 10            Argentina       12795000.0
# 11             Pakistan       12130000.0
# 12                Egypt       11893000.0
# 13               Brazil       11748000.0
# 14                Japan       11294000.0
# 15                China       11106000.0
# 16          Philippines       11100000.0
# 17               Russia       10452000.0
# 18               Turkey       10061000.0
# 19               France        9904000.0
# 20         Korea, South        9796000.0
# 21              Nigeria        9466000.0
# 22            Indonesia        9125000.0
# 23                China        8829000.0
# 24        United States        8675982.0
# 25       United Kingdom        8567000.0
# 26                 Peru        8012000.0
# 27                 Iran        7873000.0
# 28     Congo (Kinshasa)        7843000.0
# 29             Colombia        7772000.0
# ...                 ...              ...
# 13452            Russia             10.0
# 13453            Russia             10.0
# 13454            Russia             10.0
# 13455            Russia             10.0
# 13456            Russia             10.0
# 13457            Russia             10.0
# 13458            Russia             10.0
# 13459            Russia             10.0
# 13460            Russia             10.0
# 13461            Russia             10.0
# 13462            Russia             10.0
# 13463            Russia             10.0
# 13464            Russia             10.0
# 13465        Mauritania             10.0
# 13466            Russia             10.0
# 13467            Russia             10.0
# 13468            Russia             10.0
# 13469            Russia             10.0
# 13470            Russia             10.0
# 13471            Russia             10.0
# 13472            Russia             10.0
# 13473            Russia             10.0
# 13474            Russia             10.0
# 13475            Canada             10.0
# 13476         Greenland             10.0
# 13477         Greenland             10.0
# 13478           Ukraine              0.0
# 13479            Russia              0.0
# 13480            Russia              0.0
# 13481            Canada              0.0
#
# [13482 rows x 6 columns]

# %%
Ciudades_Mas_De_10_Tweets = (ciudades_list.loc[:,'ocurrencia'] > 5)

# %%
fig, ax= plt.subplots(figsize = (10, 10))
Plot = sns.scatterplot(x = "veracidad", y = "cant_habitantes", data = ciudades_list.loc[Ciudades_Mas_De_10_Tweets], ax = ax)

Plot.set_xlabel("Veracidad", labelpad=20, weight='bold', size=16)
Plot.set_ylabel("Cantidad de habitantes", labelpad=20, weight='bold', size=16)
Plot.set_title("Cantidad de habitantes Vs. Veracidad", weight='bold', size=20)
# Out:
# Text(0.5,1,'Cantidad de habitantes Vs. Veracidad')

# %%
fig, ax= plt.subplots(figsize = (10, 10))
Plot = sns.scatterplot(x = "veracidad", y = "ocurrencia", data = ciudades_list.loc[Ciudades_Mas_De_10_Tweets], ax = ax)

Plot.set_xlabel("Veracidad", labelpad=20, weight='bold', size=16)
Plot.set_ylabel("Cantidad de Tweets", labelpad=20, weight='bold', size=16)
Plot.set_title("Cantidad de Tweets Vs. Veracidad (Por ciudad)", weight='bold', size=20)
# Out:
# Text(0.5,1,'Cantidad de Tweets Vs. Veracidad (Por ciudad)')

# %%
cmap = cm.get_cmap('YlOrBr')
paleta = cmap(np.linspace(0.3, 0.9,100))

colores_rgb = []
for i in paleta:
    #convierto rgba en rgb
    aux = list(i)
    del aux[3]
    aux = (int(x * 255) for x in aux)
    aux =tuple(aux)
    colores_rgb.append((aux))

# %%
type(colores_rgb)
# Out:
# list

# %%
# prepare some data
x = ciudades_list.loc[Ciudades_Mas_De_10_Tweets]['veracidad']
y = ciudades_list.loc[Ciudades_Mas_De_10_Tweets]['ocurrencia']
radii = np.sqrt(ciudades_list.loc[Ciudades_Mas_De_10_Tweets]['cant_habitantes'])/7e4
colors = [
    "#%02x%02x%02x" % i for i in colores_rgb
]

# output to static HTML file (with CDN resources)
output_file("Veracidad_Vs_Cantidad de Tweets.html", title="color_scatter.py example", mode="cdn")

TOOLS = "crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0, 1), y_range=(0, 150), width=1000, height=1000)

# add a circle renderer with vectorized colors and sizes
p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

p.title.text = "Veracidad Vs. Cantidad de Tweets (Por ciudad)"
p.legend.location = "top"
p.xaxis.axis_label = 'Veracidad promedio'
p.yaxis.axis_label = 'Cantidad de Tweets'

# show the results
show(p)
# Out:
# /home/ezezbogar/anaconda2/lib/python2.7/site-packages/bokeh/models/plots.py:756: UserWarning:
# You are attempting to set `plot.legend.location` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with the 'legend' parameter set.
#
#   warnings.warn(_LEGEND_EMPTY_WARNING % attr)

# %%
# prepare some data
x = ciudades_list.loc[Ciudades_Mas_De_10_Tweets]['veracidad']
y = ciudades_list.loc[Ciudades_Mas_De_10_Tweets]['cant_habitantes']/1e5
radii = np.sqrt(ciudades_list.loc[Ciudades_Mas_De_10_Tweets]['ocurrencia'])/1e2
# output to static HTML file (with CDN resources)
output_file("Veracidad_Vs_Cantidad de Habitantes.html", title="color_scatter.py example", mode="cdn")

TOOLS = "crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
q = figure(tools=TOOLS, x_range=(0, 1), y_range=(0, 150), width=1000, height=1000)

# add a circle renderer with vectorized colors and sizes
q.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

q.title.text = "Veracidad Vs. Cantidad de Habitantes (Por ciudad)"
q.legend.location = "top"
q.xaxis.axis_label = 'Veracidad promedio'
q.yaxis.axis_label = 'Cantidad de Habitantes (x1e5)'

# show the results
show(q)

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world.count()
# Out:
# pop_est       177
# continent     177
# name          177
# iso_a3        177
# gdp_md_est    177
# geometry      177
# dtype: int64

# %%
iso3 = pd.DataFrame({'iso3': ciudades['iso3']})
iso3 = iso3.drop_duplicates('iso3', keep = 'first')
iso3 = iso3.reset_index(drop = True)
Tweets_Paises['iso3']=iso3['iso3']

# %%
#CUIDADO AL EJECUTAR ESTO xD
for w in range(world['name'].count()):
    
    code_pais = world.loc[w, 'iso_a3']
    
    el_code_es_del_pais = Tweets_Paises.loc[:, 'iso3'] == code_pais
    
    codigo_del_pais = Tweets_Paises.loc[el_code_es_del_pais]
    
    world.loc[w, 'veracidad'] = np.nan
    
    if codigo_del_pais['Cantidad_Tweets'].sum() > 5:
        
        world.loc[w, 'veracidad'] = codigo_del_pais['Veracidad'].sum()

# %%
world
# Out:
#        pop_est                continent                      name iso_a3  \
# 0       920938                  Oceania                      Fiji    FJI
# 1     53950935                   Africa                  Tanzania    TZA
# 2       603253                   Africa                 W. Sahara    ESH
# 3     35623680            North America                    Canada    CAN
# 4    326625791            North America  United States of America    USA
# 5     18556698                     Asia                Kazakhstan    KAZ
# 6     29748859                     Asia                Uzbekistan    UZB
# 7      6909701                  Oceania          Papua New Guinea    PNG
# 8    260580739                     Asia                 Indonesia    IDN
# 9     44293293            South America                 Argentina    ARG
# 10    17789267            South America                     Chile    CHL
# 11    83301151                   Africa           Dem. Rep. Congo    COD
# 12     7531386                   Africa                   Somalia    SOM
# 13    47615739                   Africa                     Kenya    KEN
# 14    37345935                   Africa                     Sudan    SDN
# 15    12075985                   Africa                      Chad    TCD
# 16    10646714            North America                     Haiti    HTI
# 17    10734247            North America            Dominican Rep.    DOM
# 18   142257519                   Europe                    Russia    RUS
# 19      329988            North America                   Bahamas    BHS
# 20        2931            South America              Falkland Is.    FLK
# 21     5320045                   Europe                    Norway    -99
# 22       57713            North America                 Greenland    GRL
# 23         140  Seven seas (open ocean)    Fr. S. Antarctic Lands    ATF
# 24     1291358                     Asia               Timor-Leste    TLS
# 25    54841552                   Africa              South Africa    ZAF
# 26     1958042                   Africa                   Lesotho    LSO
# 27   124574795            North America                    Mexico    MEX
# 28     3360148            South America                   Uruguay    URY
# 29   207353391            South America                    Brazil    BRA
# ..         ...                      ...                       ...    ...
# 147  104256076                     Asia               Philippines    PHL
# 148   31381992                     Asia                  Malaysia    MYS
# 149     443593                     Asia                    Brunei    BRN
# 150    1972126                   Europe                  Slovenia    SVN
# 151    5491218                   Europe                   Finland    FIN
# 152    5445829                   Europe                  Slovakia    SVK
# 153   10674723                   Europe                   Czechia    CZE
# 154    5918919                   Africa                   Eritrea    ERI
# 155  126451398                     Asia                     Japan    JPN
# 156    6943739            South America                  Paraguay    PRY
# 157   28036829                     Asia                     Yemen    YEM
# 158   28571770                     Asia              Saudi Arabia    SAU
# 159       4050               Antarctica                Antarctica    ATA
# 160     265100                     Asia                 N. Cyprus    -99
# 161    1221549                     Asia                    Cyprus    CYP
# 162   33986655                   Africa                   Morocco    MAR
# 163   97041072                   Africa                     Egypt    EGY
# 164    6653210                   Africa                     Libya    LBY
# 165  105350020                   Africa                  Ethiopia    ETH
# 166     865267                   Africa                  Djibouti    DJI
# 167    3500000                   Africa                Somaliland    -99
# 168   39570125                   Africa                    Uganda    UGA
# 169   11901484                   Africa                    Rwanda    RWA
# 170    3856181                   Europe          Bosnia and Herz.    BIH
# 171    2103721                   Europe                 Macedonia    MKD
# 172    7111024                   Europe                    Serbia    SRB
# 173     642550                   Europe                Montenegro    MNE
# 174    1895250                   Europe                    Kosovo    -99
# 175    1218208            North America       Trinidad and Tobago    TTO
# 176   13026129                   Africa                  S. Sudan    SSD
#
#      gdp_md_est                                           geometry  veracidad
# 0        8374.0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...        NaN
# 1      150600.0  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...        NaN
# 2         906.5  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...        NaN
# 3     1674000.0  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...   0.531532
# 4    18560000.0  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...   0.440189
# 5      460700.0  POLYGON ((87.35997 49.21498, 86.59878 48.54918...   0.500000
# 6      202300.0  POLYGON ((55.96819 41.30864, 55.92892 44.99586...        NaN
# 7       28020.0  MULTIPOLYGON (((141.00021 -2.60015, 142.73525 ...        NaN
# 8     3028000.0  MULTIPOLYGON (((141.00021 -2.60015, 141.01706 ...   0.666667
# 9      879400.0  MULTIPOLYGON (((-68.63401 -52.63637, -68.25000...   0.375000
# 10     436100.0  MULTIPOLYGON (((-68.63401 -52.63637, -68.63335...        NaN
# 11      66010.0  POLYGON ((29.34000 -4.49998, 29.51999 -5.41998...        NaN
# 12       4719.0  POLYGON ((41.58513 -1.68325, 40.99300 -0.85829...        NaN
# 13     152700.0  POLYGON ((39.20222 -4.67677, 37.76690 -3.67712...   0.785714
# 14     176300.0  POLYGON ((24.56737 8.22919, 23.80581 8.66632, ...   0.222222
# 15      30590.0  POLYGON ((23.83766 19.58047, 23.88689 15.61084...        NaN
# 16      19340.0  POLYGON ((-71.71236 19.71446, -71.62487 19.169...        NaN
# 17     161900.0  POLYGON ((-71.70830 18.04500, -71.68774 18.316...        NaN
# 18    3745000.0  MULTIPOLYGON (((178.72530 71.09880, 180.00000 ...   0.285714
# 19       9066.0  MULTIPOLYGON (((-78.98000 26.79000, -78.51000 ...        NaN
# 20        281.8  POLYGON ((-61.20000 -51.85000, -60.00000 -51.2...        NaN
# 21     364700.0  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...        NaN
# 22       2173.0  POLYGON ((-46.76379 82.62796, -43.40644 83.225...        NaN
# 23         16.0  POLYGON ((68.93500 -48.62500, 69.58000 -48.940...        NaN
# 24       4975.0  POLYGON ((124.96868 -8.89279, 125.08625 -8.656...        NaN
# 25     739100.0  POLYGON ((16.34498 -28.57671, 16.82402 -28.082...   0.368421
# 26       6019.0  POLYGON ((28.97826 -28.95560, 29.32517 -29.257...        NaN
# 27    2307000.0  POLYGON ((-117.12776 32.53534, -115.99135 32.6...   0.500000
# 28      73250.0  POLYGON ((-57.62513 -30.21629, -56.97603 -30.1...   0.371429
# 29    3081000.0  POLYGON ((-53.37366 -33.76838, -53.65054 -33.2...   0.312500
# ..          ...                                                ...        ...
# 147    801900.0  MULTIPOLYGON (((120.83390 12.70450, 120.32344 ...   0.461538
# 148    863000.0  MULTIPOLYGON (((100.08576 6.46449, 100.25960 6...   0.714286
# 149     33730.0  POLYGON ((115.45071 5.44773, 115.40570 4.95523...        NaN
# 150     68350.0  POLYGON ((13.80648 46.50931, 14.63247 46.43182...        NaN
# 151    224137.0  POLYGON ((28.59193 69.06478, 28.44594 68.36461...        NaN
# 152    168800.0  POLYGON ((22.55814 49.08574, 22.28084 48.82539...        NaN
# 153    350900.0  POLYGON ((15.01700 51.10667, 15.49097 50.78473...        NaN
# 154      9169.0  POLYGON ((36.42951 14.42211, 36.32322 14.82249...        NaN
# 155   4932000.0  MULTIPOLYGON (((141.88460 39.18086, 140.95949 ...   0.538462
# 156     64670.0  POLYGON ((-58.16639 -20.17670, -57.87067 -20.7...        NaN
# 157     73450.0  POLYGON ((52.00001 19.00000, 52.78218 17.34974...        NaN
# 158   1731000.0  POLYGON ((34.95604 29.35655, 36.06894 29.19749...        NaN
# 159       810.0  MULTIPOLYGON (((-48.66062 -78.04702, -48.15140...        NaN
# 160      3600.0  POLYGON ((32.73178 35.14003, 32.80247 35.14550...        NaN
# 161     29260.0  POLYGON ((32.73178 35.14003, 32.91957 35.08783...        NaN
# 162    282800.0  POLYGON ((-2.16991 35.16840, -1.79299 34.52792...        NaN
# 163   1105000.0  POLYGON ((36.86623 22.00000, 32.90000 22.00000...   0.666667
# 164     90890.0  POLYGON ((25.00000 22.00000, 25.00000 20.00304...        NaN
# 165    174700.0  POLYGON ((47.78942 8.00300, 44.96360 5.00162, ...        NaN
# 166      3345.0  POLYGON ((42.35156 12.54223, 42.77964 12.45542...        NaN
# 167     12250.0  POLYGON ((48.94820 11.41062, 48.94820 11.41062...        NaN
# 168     84930.0  POLYGON ((33.90371 -0.95000, 31.86617 -1.02736...        NaN
# 169     21970.0  POLYGON ((30.41910 -1.13466, 30.81613 -1.69891...        NaN
# 170     42530.0  POLYGON ((18.56000 42.65000, 17.67492 43.02856...        NaN
# 171     29520.0  POLYGON ((22.38053 42.32026, 22.88137 41.99930...        NaN
# 172    101800.0  POLYGON ((18.82982 45.90887, 18.82984 45.90888...        NaN
# 173     10610.0  POLYGON ((20.07070 42.58863, 19.80161 42.50009...        NaN
# 174     18490.0  POLYGON ((20.59025 41.85541, 20.52295 42.21787...        NaN
# 175     43570.0  POLYGON ((-61.68000 10.76000, -61.10500 10.890...        NaN
# 176     20880.0  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...        NaN
#
# [177 rows x 7 columns]

# %%
fig, ax = plt.subplots(figsize = (150, 20))
world = world[world.name!="Antarctica"]

ax.patch.set_facecolor('#eeeeee')

world.plot(column='veracidad', ax = ax, legend = True, cmap='OrRd')
# Out:
# /home/ezezbogar/anaconda2/lib/python2.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
